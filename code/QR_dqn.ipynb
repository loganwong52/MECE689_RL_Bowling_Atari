# %% [markdown]
# QR DQN
#
# Logan Wong
#
# law3082

# %%
# REMINDER: make sure you set
# Runtime
# Change runtime type
# T4 GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari
# !ls -la
# Out:
# /content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari
# total 29
# drwx------ 2 root root 4096 Sep 25 15:17 checkpoints
# drwx------ 2 root root 4096 Sep 25 15:17 code
# drwx------ 2 root root 4096 Sep 25 15:04 .git
# -rw------- 1 root root 6087 Sep 30 00:04 github_terminal.ipynb
# -rw------- 1 root root   33 Sep 26 19:25 .gitignore
# drwx------ 2 root root 4096 Sep 25 15:17 models
# -rw------- 1 root root 2348 Sep 29 02:21 README.md
# drwx------ 2 root root 4096 Sep 25 15:17 results

# %%
# !pip install gymnasium[atari,accept-rom-license] ale-py sb3_contrib stable-baselines3
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: sb3_contrib in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (1.2.1)
# WARNING: gymnasium 1.2.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)

# %%
import os
import torch
import gymnasium as gym
import stable_baselines3
import ale_py
import numpy as np
from sb3_contrib import QRDQN


# Visualization
from PIL import Image
import io
import base64
from IPython.display import display, HTML



# For debugging
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.callbacks import BaseCallback
import time

# Action masking
from gymnasium import ActionWrapper
from stable_baselines3.common.atari_wrappers import AtariWrapper

# Vector environment
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack, VecEnvWrapper, DummyVecEnv


import gc

print("All imports working")
# Out:
# All imports working

# %%
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# GPU available: True
# GPU: Tesla T4

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %%
# # Show the first frame as an image
# def show_frame(obs):
#     # Convert to PIL Image and display
#     img = Image.fromarray(obs)
#     display(img)

# %% [markdown]
# Create Environment and Model

# %%
# Action space: Discrete(6)
# Number of actions: 6
# Action meanings: ['NOOP', 'FIRE', 'UP', 'DOWN', 'UPFIRE', 'DOWNFIRE']
# Observation shape: (210, 160, 3)
# Observation space: Box(0, 255, (210, 160, 3), uint8)

# ACTIONS:
# 0: NOOP
# 1: FIRE
# 2: UP
# 3: DOWN

# 4: UPFIRE
# 5: DOWNFIRE

# %%
class ActionReducer(ActionWrapper):
  def __init__(self, env):
    super().__init__(env)

    # NOOP, FIRE, UP, and DOWN only. No UPFIRE. No DOWNFIRE.
    self.allowed_actions = [0,1,2,3]

    self.action_space = gym.spaces.Discrete(len(self.allowed_actions))

  def action(self, action):
    return self.allowed_actions[action]

# %%
def make_env():
  # DQN only supports single environments (not vectorized)
  env = gym.make("ALE/Bowling-v5")
  env = ActionReducer(env)
  env = Monitor(env)
  # disable reward clipping
  env = AtariWrapper(env, clip_reward=False)
  return env

# %%
seed = 316
torch.manual_seed(seed)

env = DummyVecEnv([make_env])
env = VecFrameStack(env, n_stack=4)

model = QRDQN(
    "CnnPolicy",
    env,
    learning_rate=0.0001,
    buffer_size=50000,
    batch_size=32,
    gamma=0.99,
    target_update_interval=1000,
    train_freq=4,
    gradient_steps=1,
    exploration_final_eps=0.02,
    exploration_fraction=0.1,
    learning_starts=10000,
    verbose=1,
    device="cuda"
)

print("QR-DQN model created")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# QR-DQN model created
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# # Confirm number of possible actions is smaller now
# print(f"Original action space: {gym.make('ALE/Bowling-v5').action_space}")
# print(f"Reduced action space: {env.action_space}")

# %% [markdown]
# Train the model

# %%
class SimpleCheckpointCallback(BaseCallback):
    def __init__(self, save_freq, save_path, name_prefix):
        super().__init__()
        self.save_freq = save_freq
        self.save_path = save_path
        self.name_prefix = name_prefix

    def _on_step(self):
        if self.n_calls % self.save_freq == 0:
            path = os.path.join(self.save_path, f"{self.name_prefix}_{self.n_calls}")
            self.model.save(path)
            print(f"Checkpoint saved at step {self.n_calls}")
        return True

# %%
total_timesteps = 10000000    # 10M
# total_timesteps = 5000000    # 5M
# total_timesteps =  2000000    # 2M
# total_timesteps =  1000000    # 1M
# total_timesteps =   100000    # 100K
# total_timesteps =    10000    # 10K
# total_timesteps =     5000    # 5K

# Save couple of steps
checkpoint_callback = CheckpointCallback(
    save_freq=100000,
    save_path="/content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari/checkpoints",
    name_prefix=f"qr_dqn_{total_timesteps}"
)

# Time how long it takes
print("Training started")
start_time = time.time()

# log_interval: Print train metrics every 10 episodes
model.learn(
    total_timesteps=total_timesteps,
    callback=checkpoint_callback,
    progress_bar=True,
    log_interval=10
)
end_time = time.time()
print("Training done")

env.close()

# Calculate run time
training_duration = end_time - start_time
time_in_minutes_and_seconds = convert(training_duration)
print(f"Time taken: {time_in_minutes_and_seconds}")
# print(f"Speed: {total_timesteps/training_duration:.2f} steps/second")

# Save model to Google Drive
trained_model_save_path = f"/content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari/models/qr_dqn{total_timesteps}"
model.save(trained_model_save_path)
print("Model saved to Google Drive")
# Out:
# Output()
# /usr/local/lib/python3.12/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46.1     |
# |    n_updates        | 1473290  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9310     |
# |    fps              | 184      |
# |    time_elapsed     | 32036    |
# |    total_timesteps  | 5908472  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.5     |
# |    n_updates        | 1474617  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9320     |
# |    fps              | 184      |
# |    time_elapsed     | 32063    |
# |    total_timesteps  | 5913445  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 83.8     |
# |    n_updates        | 1475861  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9330     |
# |    fps              | 184      |
# |    time_elapsed     | 32093    |
# |    total_timesteps  | 5918971  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 72.6     |
# |    n_updates        | 1477242  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9340     |
# |    fps              | 184      |
# |    time_elapsed     | 32122    |
# |    total_timesteps  | 5924149  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.6     |
# |    n_updates        | 1478537  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9350     |
# |    fps              | 184      |
# |    time_elapsed     | 32151    |
# |    total_timesteps  | 5929465  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 71.8     |
# |    n_updates        | 1479866  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9360     |
# |    fps              | 184      |
# |    time_elapsed     | 32181    |
# |    total_timesteps  | 5934915  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 61.7     |
# |    n_updates        | 1481228  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9370     |
# |    fps              | 184      |
# |    time_elapsed     | 32211    |
# |    total_timesteps  | 5940353  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.4     |
# |    n_updates        | 1482588  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9380     |
# |    fps              | 184      |
# |    time_elapsed     | 32238    |
# |    total_timesteps  | 5945417  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.4     |
# |    n_updates        | 1483854  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9390     |
# |    fps              | 184      |
# |    time_elapsed     | 32271    |
# |    total_timesteps  | 5951191  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.6     |
# |    n_updates        | 1485297  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9400     |
# |    fps              | 184      |
# |    time_elapsed     | 32300    |
# |    total_timesteps  | 5956375  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 70.7     |
# |    n_updates        | 1486593  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9410     |
# |    fps              | 184      |
# |    time_elapsed     | 32331    |
# |    total_timesteps  | 5962152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 92.9     |
# |    n_updates        | 1488037  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9420     |
# |    fps              | 184      |
# |    time_elapsed     | 32359    |
# |    total_timesteps  | 5967210  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 83.6     |
# |    n_updates        | 1489302  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9430     |
# |    fps              | 184      |
# |    time_elapsed     | 32388    |
# |    total_timesteps  | 5972441  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.3     |
# |    n_updates        | 1490610  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9440     |
# |    fps              | 184      |
# |    time_elapsed     | 32418    |
# |    total_timesteps  | 5977740  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 66.3     |
# |    n_updates        | 1491934  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9450     |
# |    fps              | 184      |
# |    time_elapsed     | 32447    |
# |    total_timesteps  | 5983170  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.4     |
# |    n_updates        | 1493292  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9460     |
# |    fps              | 184      |
# |    time_elapsed     | 32477    |
# |    total_timesteps  | 5988536  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.7     |
# |    n_updates        | 1494633  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9470     |
# |    fps              | 184      |
# |    time_elapsed     | 32505    |
# |    total_timesteps  | 5993544  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 87.8     |
# |    n_updates        | 1495885  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9480     |
# |    fps              | 184      |
# |    time_elapsed     | 32534    |
# |    total_timesteps  | 5998688  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 59.3     |
# |    n_updates        | 1497171  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9490     |
# |    fps              | 184      |
# |    time_elapsed     | 32564    |
# |    total_timesteps  | 6004039  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.3     |
# |    n_updates        | 1498509  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9500     |
# |    fps              | 184      |
# |    time_elapsed     | 32592    |
# |    total_timesteps  | 6009043  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 40.1     |
# |    n_updates        | 1499760  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9510     |
# |    fps              | 184      |
# |    time_elapsed     | 32619    |
# |    total_timesteps  | 6014119  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.5     |
# |    n_updates        | 1501029  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9520     |
# |    fps              | 184      |
# |    time_elapsed     | 32647    |
# |    total_timesteps  | 6019236  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 65.6     |
# |    n_updates        | 1502308  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9530     |
# |    fps              | 184      |
# |    time_elapsed     | 32675    |
# |    total_timesteps  | 6024274  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 40.2     |
# |    n_updates        | 1503568  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9540     |
# |    fps              | 184      |
# |    time_elapsed     | 32703    |
# |    total_timesteps  | 6029398  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 76.7     |
# |    n_updates        | 1504849  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9550     |
# |    fps              | 184      |
# |    time_elapsed     | 32735    |
# |    total_timesteps  | 6035126  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 117      |
# |    n_updates        | 1506281  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9560     |
# |    fps              | 184      |
# |    time_elapsed     | 32765    |
# |    total_timesteps  | 6040614  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69.6     |
# |    n_updates        | 1507653  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9570     |
# |    fps              | 184      |
# |    time_elapsed     | 32795    |
# |    total_timesteps  | 6045924  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 25.7     |
# |    n_updates        | 1508980  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9580     |
# |    fps              | 184      |
# |    time_elapsed     | 32824    |
# |    total_timesteps  | 6051086  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 65       |
# |    n_updates        | 1510271  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9590     |
# |    fps              | 184      |
# |    time_elapsed     | 32852    |
# |    total_timesteps  | 6056272  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69.6     |
# |    n_updates        | 1511567  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9600     |
# |    fps              | 184      |
# |    time_elapsed     | 32883    |
# |    total_timesteps  | 6061584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.8     |
# |    n_updates        | 1512895  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9610     |
# |    fps              | 184      |
# |    time_elapsed     | 32912    |
# |    total_timesteps  | 6067023  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.5     |
# |    n_updates        | 1514255  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9620     |
# |    fps              | 184      |
# |    time_elapsed     | 32945    |
# |    total_timesteps  | 6072953  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.7     |
# |    n_updates        | 1515738  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9630     |
# |    fps              | 184      |
# |    time_elapsed     | 32976    |
# |    total_timesteps  | 6078600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.2     |
# |    n_updates        | 1517149  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9640     |
# |    fps              | 184      |
# |    time_elapsed     | 33007    |
# |    total_timesteps  | 6084242  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 88.4     |
# |    n_updates        | 1518560  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9650     |
# |    fps              | 184      |
# |    time_elapsed     | 33037    |
# |    total_timesteps  | 6089607  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.7     |
# |    n_updates        | 1519901  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9660     |
# |    fps              | 184      |
# |    time_elapsed     | 33065    |
# |    total_timesteps  | 6094862  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 92.5     |
# |    n_updates        | 1521215  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9670     |
# |    fps              | 184      |
# |    time_elapsed     | 33098    |
# |    total_timesteps  | 6100683  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 70.7     |
# |    n_updates        | 1522670  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9680     |
# |    fps              | 184      |
# |    time_elapsed     | 33128    |
# |    total_timesteps  | 6106029  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.2     |
# |    n_updates        | 1524007  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9690     |
# |    fps              | 184      |
# |    time_elapsed     | 33158    |
# |    total_timesteps  | 6111636  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.8     |
# |    n_updates        | 1525408  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9700     |
# |    fps              | 184      |
# |    time_elapsed     | 33194    |
# |    total_timesteps  | 6118031  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 56.5     |
# |    n_updates        | 1527007  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9710     |
# |    fps              | 184      |
# |    time_elapsed     | 33223    |
# |    total_timesteps  | 6123443  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.7     |
# |    n_updates        | 1528360  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9720     |
# |    fps              | 184      |
# |    time_elapsed     | 33253    |
# |    total_timesteps  | 6128826  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.4     |
# |    n_updates        | 1529706  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9730     |
# |    fps              | 184      |
# |    time_elapsed     | 33285    |
# |    total_timesteps  | 6134551  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46.8     |
# |    n_updates        | 1531137  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9740     |
# |    fps              | 184      |
# |    time_elapsed     | 33314    |
# |    total_timesteps  | 6139930  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.2     |
# |    n_updates        | 1532482  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9750     |
# |    fps              | 184      |
# |    time_elapsed     | 33342    |
# |    total_timesteps  | 6145088  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 26.8     |
# |    n_updates        | 1533771  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9760     |
# |    fps              | 184      |
# |    time_elapsed     | 33372    |
# |    total_timesteps  | 6150508  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.2     |
# |    n_updates        | 1535126  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9770     |
# |    fps              | 184      |
# |    time_elapsed     | 33402    |
# |    total_timesteps  | 6155858  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 46.3     |
# |    n_updates        | 1536464  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9780     |
# |    fps              | 184      |
# |    time_elapsed     | 33430    |
# |    total_timesteps  | 6160903  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 23.2     |
# |    n_updates        | 1537725  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9790     |
# |    fps              | 184      |
# |    time_elapsed     | 33458    |
# |    total_timesteps  | 6166111  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69       |
# |    n_updates        | 1539027  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9800     |
# |    fps              | 184      |
# |    time_elapsed     | 33487    |
# |    total_timesteps  | 6171444  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54.6     |
# |    n_updates        | 1540360  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9810     |
# |    fps              | 184      |
# |    time_elapsed     | 33518    |
# |    total_timesteps  | 6177032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.4     |
# |    n_updates        | 1541757  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9820     |
# |    fps              | 184      |
# |    time_elapsed     | 33548    |
# |    total_timesteps  | 6182512  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.1     |
# |    n_updates        | 1543127  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9830     |
# |    fps              | 184      |
# |    time_elapsed     | 33583    |
# |    total_timesteps  | 6188853  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42.2     |
# |    n_updates        | 1544713  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9840     |
# |    fps              | 184      |
# |    time_elapsed     | 33610    |
# |    total_timesteps  | 6193837  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 67.2     |
# |    n_updates        | 1545959  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9850     |
# |    fps              | 184      |
# |    time_elapsed     | 33641    |
# |    total_timesteps  | 6199333  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 49.8     |
# |    n_updates        | 1547333  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9860     |
# |    fps              | 184      |
# |    time_elapsed     | 33670    |
# |    total_timesteps  | 6204569  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.9     |
# |    n_updates        | 1548642  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 99.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9870     |
# |    fps              | 184      |
# |    time_elapsed     | 33698    |
# |    total_timesteps  | 6209658  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 25.6     |
# |    n_updates        | 1549914  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 99.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9880     |
# |    fps              | 184      |
# |    time_elapsed     | 33729    |
# |    total_timesteps  | 6215347  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 29       |
# |    n_updates        | 1551336  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 99.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9890     |
# |    fps              | 184      |
# |    time_elapsed     | 33761    |
# |    total_timesteps  | 6221181  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 73.5     |
# |    n_updates        | 1552795  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9900     |
# |    fps              | 184      |
# |    time_elapsed     | 33791    |
# |    total_timesteps  | 6226519  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.3     |
# |    n_updates        | 1554129  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9910     |
# |    fps              | 184      |
# |    time_elapsed     | 33823    |
# |    total_timesteps  | 6232566  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.7     |
# |    n_updates        | 1555641  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9920     |
# |    fps              | 184      |
# |    time_elapsed     | 33854    |
# |    total_timesteps  | 6238007  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 53.2     |
# |    n_updates        | 1557001  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9930     |
# |    fps              | 184      |
# |    time_elapsed     | 33882    |
# |    total_timesteps  | 6243068  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 53.4     |
# |    n_updates        | 1558266  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9940     |
# |    fps              | 184      |
# |    time_elapsed     | 33911    |
# |    total_timesteps  | 6248448  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 45       |
# |    n_updates        | 1559611  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9950     |
# |    fps              | 184      |
# |    time_elapsed     | 33941    |
# |    total_timesteps  | 6253936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.9     |
# |    n_updates        | 1560983  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9960     |
# |    fps              | 184      |
# |    time_elapsed     | 33972    |
# |    total_timesteps  | 6259496  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.7     |
# |    n_updates        | 1562373  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9970     |
# |    fps              | 184      |
# |    time_elapsed     | 34003    |
# |    total_timesteps  | 6265166  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 67.2     |
# |    n_updates        | 1563791  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9980     |
# |    fps              | 184      |
# |    time_elapsed     | 34031    |
# |    total_timesteps  | 6270232  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.3     |
# |    n_updates        | 1565057  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 9990     |
# |    fps              | 184      |
# |    time_elapsed     | 34060    |
# |    total_timesteps  | 6275617  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 30       |
# |    n_updates        | 1566404  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10000    |
# |    fps              | 184      |
# |    time_elapsed     | 34091    |
# |    total_timesteps  | 6281285  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.1     |
# |    n_updates        | 1567821  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10010    |
# |    fps              | 184      |
# |    time_elapsed     | 34121    |
# |    total_timesteps  | 6286645  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.5     |
# |    n_updates        | 1569161  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10020    |
# |    fps              | 184      |
# |    time_elapsed     | 34152    |
# |    total_timesteps  | 6292455  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 53.6     |
# |    n_updates        | 1570613  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10030    |
# |    fps              | 184      |
# |    time_elapsed     | 34183    |
# |    total_timesteps  | 6298044  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 59.5     |
# |    n_updates        | 1572010  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10040    |
# |    fps              | 184      |
# |    time_elapsed     | 34212    |
# |    total_timesteps  | 6303224  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 43.2     |
# |    n_updates        | 1573305  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10050    |
# |    fps              | 184      |
# |    time_elapsed     | 34241    |
# |    total_timesteps  | 6308337  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 54       |
# |    n_updates        | 1574584  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10060    |
# |    fps              | 184      |
# |    time_elapsed     | 34269    |
# |    total_timesteps  | 6313446  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 51.1     |
# |    n_updates        | 1575861  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10070    |
# |    fps              | 184      |
# |    time_elapsed     | 34296    |
# |    total_timesteps  | 6318367  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 55.5     |
# |    n_updates        | 1577091  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10080    |
# |    fps              | 184      |
# |    time_elapsed     | 34325    |
# |    total_timesteps  | 6323693  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.9     |
# |    n_updates        | 1578423  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10090    |
# |    fps              | 184      |
# |    time_elapsed     | 34354    |
# |    total_timesteps  | 6328943  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.3     |
# |    n_updates        | 1579735  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10100    |
# |    fps              | 184      |
# |    time_elapsed     | 34383    |
# |    total_timesteps  | 6334208  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.8     |
# |    n_updates        | 1581051  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10110    |
# |    fps              | 184      |
# |    time_elapsed     | 34413    |
# |    total_timesteps  | 6339527  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.3     |
# |    n_updates        | 1582381  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10120    |
# |    fps              | 184      |
# |    time_elapsed     | 34442    |
# |    total_timesteps  | 6344948  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 45.2     |
# |    n_updates        | 1583736  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10130    |
# |    fps              | 184      |
# |    time_elapsed     | 34472    |
# |    total_timesteps  | 6350286  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48.1     |
# |    n_updates        | 1585071  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10140    |
# |    fps              | 184      |
# |    time_elapsed     | 34502    |
# |    total_timesteps  | 6355677  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.1     |
# |    n_updates        | 1586419  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10150    |
# |    fps              | 184      |
# |    time_elapsed     | 34530    |
# |    total_timesteps  | 6360778  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52       |
# |    n_updates        | 1587694  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10160    |
# |    fps              | 184      |
# |    time_elapsed     | 34559    |
# |    total_timesteps  | 6365967  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38       |
# |    n_updates        | 1588991  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10170    |
# |    fps              | 184      |
# |    time_elapsed     | 34590    |
# |    total_timesteps  | 6371583  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.9     |
# |    n_updates        | 1590395  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10180    |
# |    fps              | 184      |
# |    time_elapsed     | 34617    |
# |    total_timesteps  | 6376546  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.4     |
# |    n_updates        | 1591636  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10190    |
# |    fps              | 184      |
# |    time_elapsed     | 34645    |
# |    total_timesteps  | 6381511  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31.2     |
# |    n_updates        | 1592877  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10200    |
# |    fps              | 184      |
# |    time_elapsed     | 34672    |
# |    total_timesteps  | 6386566  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 25.8     |
# |    n_updates        | 1594141  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 10210    |
# ...
# |    time_elapsed     | 41082    |
# |    total_timesteps  | 7551472  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.7     |
# |    n_updates        | 1885367  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12370    |
# |    fps              | 183      |
# |    time_elapsed     | 41113    |
# |    total_timesteps  | 7557090  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 62.7     |
# |    n_updates        | 1886772  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12380    |
# |    fps              | 183      |
# |    time_elapsed     | 41141    |
# |    total_timesteps  | 7562236  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 62.4     |
# |    n_updates        | 1888058  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12390    |
# |    fps              | 183      |
# |    time_elapsed     | 41170    |
# |    total_timesteps  | 7567395  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 53.4     |
# |    n_updates        | 1889348  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12400    |
# |    fps              | 183      |
# |    time_elapsed     | 41199    |
# |    total_timesteps  | 7572599  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.1     |
# |    n_updates        | 1890649  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12410    |
# |    fps              | 183      |
# |    time_elapsed     | 41232    |
# |    total_timesteps  | 7578405  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 42       |
# |    n_updates        | 1892101  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12420    |
# |    fps              | 183      |
# |    time_elapsed     | 41261    |
# |    total_timesteps  | 7583582  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 45.9     |
# |    n_updates        | 1893395  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12430    |
# |    fps              | 183      |
# |    time_elapsed     | 41289    |
# |    total_timesteps  | 7588554  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 39.9     |
# |    n_updates        | 1894638  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12440    |
# |    fps              | 183      |
# |    time_elapsed     | 41317    |
# |    total_timesteps  | 7593711  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 50.1     |
# |    n_updates        | 1895927  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12450    |
# |    fps              | 183      |
# |    time_elapsed     | 41346    |
# |    total_timesteps  | 7598865  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 60.7     |
# |    n_updates        | 1897216  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12460    |
# |    fps              | 183      |
# |    time_elapsed     | 41376    |
# |    total_timesteps  | 7604094  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 47.8     |
# |    n_updates        | 1898523  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12470    |
# |    fps              | 183      |
# |    time_elapsed     | 41407    |
# |    total_timesteps  | 7609573  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 80       |
# |    n_updates        | 1899893  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 121      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12480    |
# |    fps              | 183      |
# |    time_elapsed     | 41436    |
# |    total_timesteps  | 7614663  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.7     |
# |    n_updates        | 1901165  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12490    |
# |    fps              | 183      |
# |    time_elapsed     | 41465    |
# |    total_timesteps  | 7619874  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 48.8     |
# |    n_updates        | 1902468  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12500    |
# |    fps              | 183      |
# |    time_elapsed     | 41499    |
# |    total_timesteps  | 7625672  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 58.5     |
# |    n_updates        | 1903917  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12510    |
# |    fps              | 183      |
# |    time_elapsed     | 41528    |
# |    total_timesteps  | 7630827  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.7     |
# |    n_updates        | 1905206  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12520    |
# |    fps              | 183      |
# |    time_elapsed     | 41558    |
# |    total_timesteps  | 7636194  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 106      |
# |    n_updates        | 1906548  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12530    |
# |    fps              | 183      |
# |    time_elapsed     | 41587    |
# |    total_timesteps  | 7641389  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 41.5     |
# |    n_updates        | 1907847  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12540    |
# |    fps              | 183      |
# |    time_elapsed     | 41613    |
# |    total_timesteps  | 7646205  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 58.8     |
# |    n_updates        | 1909051  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12550    |
# |    fps              | 183      |
# |    time_elapsed     | 41644    |
# |    total_timesteps  | 7651543  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.8     |
# |    n_updates        | 1910385  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12560    |
# |    fps              | 183      |
# |    time_elapsed     | 41672    |
# |    total_timesteps  | 7656606  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 92.8     |
# |    n_updates        | 1911651  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12570    |
# |    fps              | 183      |
# |    time_elapsed     | 41702    |
# |    total_timesteps  | 7662054  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 63.9     |
# |    n_updates        | 1913013  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12580    |
# |    fps              | 183      |
# |    time_elapsed     | 41733    |
# |    total_timesteps  | 7667663  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 52.1     |
# |    n_updates        | 1914415  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12590    |
# |    fps              | 183      |
# |    time_elapsed     | 41761    |
# |    total_timesteps  | 7672646  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 78.8     |
# |    n_updates        | 1915661  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12600    |
# |    fps              | 183      |
# |    time_elapsed     | 41788    |
# |    total_timesteps  | 7677478  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 66.1     |
# |    n_updates        | 1916869  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12610    |
# |    fps              | 183      |
# |    time_elapsed     | 41816    |
# |    total_timesteps  | 7682529  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 74.7     |
# |    n_updates        | 1918132  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12620    |
# |    fps              | 183      |
# |    time_elapsed     | 41842    |
# |    total_timesteps  | 7687256  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 78.6     |
# |    n_updates        | 1919313  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12630    |
# |    fps              | 183      |
# |    time_elapsed     | 41869    |
# |    total_timesteps  | 7692037  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 97.1     |
# |    n_updates        | 1920509  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12640    |
# |    fps              | 183      |
# |    time_elapsed     | 41899    |
# |    total_timesteps  | 7697328  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 72       |
# |    n_updates        | 1921831  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12650    |
# |    fps              | 183      |
# |    time_elapsed     | 41927    |
# |    total_timesteps  | 7702495  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 63.8     |
# |    n_updates        | 1923123  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 12660    |
# |    fps              | 183      |
# |    time_elapsed     | 41954    |
# |    total_timesteps  | 7707451  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 91.3     |
# |    n_updates        | 1924362  |
# ----------------------------------

# %%
# torch.cuda.empty_cache()
# del model
# del env
