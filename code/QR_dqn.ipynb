# %% [markdown]
# QR DQN
#
# Logan Wong
#
# law3082

# %%
# REMINDER: make sure you set
# Runtime
# Change runtime type
# T4 GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari
# !ls -la
# Out:
# /content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari
# total 30
# drwx------ 2 root root 4096 Sep 25 15:17 checkpoints
# drwx------ 2 root root 4096 Sep 25 15:17 code
# drwx------ 2 root root 4096 Sep 25 15:04 .git
# -rw------- 1 root root 6200 Oct 13 19:29 github_terminal.ipynb
# -rw------- 1 root root   33 Sep 26 19:25 .gitignore
# drwx------ 2 root root 4096 Sep 25 15:17 models
# -rw------- 1 root root 2348 Sep 29 02:21 README.md
# drwx------ 2 root root 4096 Sep 25 15:17 results

# %%
# !pip install gymnasium[atari,accept-rom-license] ale-py sb3_contrib stable-baselines3
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Collecting sb3_contrib
#   Downloading sb3_contrib-2.7.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (1.2.1)
# WARNING: gymnasium 1.2.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading sb3_contrib-2.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.2 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 19.0 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3, sb3_contrib
# Successfully installed sb3_contrib-2.7.0 stable-baselines3-2.7.0

# %%
import os
import torch
import gymnasium as gym
import stable_baselines3
import ale_py
import numpy as np
from sb3_contrib import QRDQN


# Visualization
from PIL import Image
import io
import base64
from IPython.display import display, HTML



# For debugging
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.callbacks import BaseCallback
import time

# Action masking
from gymnasium import ActionWrapper
from stable_baselines3.common.atari_wrappers import AtariWrapper

# Vector environment
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack, VecEnvWrapper, DummyVecEnv


import gc

print("All imports working")
# Out:
# All imports working
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# GPU available: True
# GPU: Tesla T4

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %%
# # Show the first frame as an image
# def show_frame(obs):
#     # Convert to PIL Image and display
#     img = Image.fromarray(obs)
#     display(img)

# %% [markdown]
# Create Environment and Model

# %%
# Action space: Discrete(6)
# Number of actions: 6
# Action meanings: ['NOOP', 'FIRE', 'UP', 'DOWN', 'UPFIRE', 'DOWNFIRE']
# Observation shape: (210, 160, 3)
# Observation space: Box(0, 255, (210, 160, 3), uint8)

# ACTIONS:
# 0: NOOP
# 1: FIRE
# 2: UP
# 3: DOWN

# 4: UPFIRE
# 5: DOWNFIRE

# %%
class ActionReducer(ActionWrapper):
  def __init__(self, env):
    super().__init__(env)

    # NOOP, FIRE, UP, and DOWN only. No UPFIRE. No DOWNFIRE.
    self.allowed_actions = [0,1,2,3]

    self.action_space = gym.spaces.Discrete(len(self.allowed_actions))

  def action(self, action):
    return self.allowed_actions[action]

# %%
def make_env():
  # DQN only supports single environments (not vectorized)
  env = gym.make("ALE/Bowling-v5")
  env = ActionReducer(env)
  env = Monitor(env)
  # disable reward clipping
  env = AtariWrapper(env, clip_reward=False)
  return env

# %%
seed = 316
torch.manual_seed(seed)

env = DummyVecEnv([make_env])
env = VecFrameStack(env, n_stack=4)

model = QRDQN(
    "CnnPolicy",
    env,
    learning_rate=0.0001,
    buffer_size=50000,
    batch_size=32,
    gamma=0.99,
    target_update_interval=1000,
    train_freq=4,
    gradient_steps=1,
    exploration_final_eps=0.02,
    exploration_fraction=0.1,
    learning_starts=10000,
    verbose=1,
    device="cuda"
)

print("QR-DQN model created")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# QR-DQN model created
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# # Confirm number of possible actions is smaller now
# print(f"Original action space: {gym.make('ALE/Bowling-v5').action_space}")
# print(f"Reduced action space: {env.action_space}")

# %% [markdown]
# Train the model

# %%
class SimpleCheckpointCallback(BaseCallback):
    def __init__(self, save_freq, save_path, name_prefix):
        super().__init__()
        self.save_freq = save_freq
        self.save_path = save_path
        self.name_prefix = name_prefix

    def _on_step(self):
        if self.n_calls % self.save_freq == 0:
            path = os.path.join(self.save_path, f"{self.name_prefix}_{self.n_calls}")
            self.model.save(path)
            print(f"Checkpoint saved at step {self.n_calls}")
        return True

# %%
total_timesteps = 10000000    # 10M
# total_timesteps = 5000000    # 5M
# total_timesteps =  2000000    # 2M
# total_timesteps =  1000000    # 1M
# total_timesteps =   100000    # 100K
# total_timesteps =    10000    # 10K
# total_timesteps =     5000    # 5K

# Save couple of steps
checkpoint_callback = CheckpointCallback(
    save_freq=100000,
    save_path="/content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari/checkpoints",
    name_prefix=f"qr_dqn_{total_timesteps}"
)

# Time how long it takes
print("Training started")
start_time = time.time()

# log_interval: Print train metrics every 10 episodes
model.learn(
    total_timesteps=total_timesteps,
    callback=checkpoint_callback,
    progress_bar=True,
    log_interval=10
)
end_time = time.time()
print("Training done")

env.close()

# Calculate run time
training_duration = end_time - start_time
time_in_minutes_and_seconds = convert(training_duration)
print(f"Time taken: {time_in_minutes_and_seconds}")
# print(f"Speed: {total_timesteps/training_duration:.2f} steps/second")

# Save model to Google Drive
trained_model_save_path = f"/content/drive/MyDrive/MECE689_Bowling/MECE689_RL_Bowling_Atari/models/qr_dqn_{total_timesteps}"
model.save(trained_model_save_path)
print("Model saved to Google Drive")
# Out:
# Output()
# /usr/local/lib/python3.12/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.3     |
# |    n_updates        | 2037239  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13410    |
# |    fps              | 184      |
# |    time_elapsed     | 44152    |
# |    total_timesteps  | 8164518  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.34     |
# |    n_updates        | 2038629  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13420    |
# |    fps              | 184      |
# |    time_elapsed     | 44182    |
# |    total_timesteps  | 8170031  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 2040007  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13430    |
# |    fps              | 184      |
# |    time_elapsed     | 44211    |
# |    total_timesteps  | 8175622  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.753    |
# |    n_updates        | 2041405  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13440    |
# |    fps              | 184      |
# |    time_elapsed     | 44241    |
# |    total_timesteps  | 8181162  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 2042790  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13450    |
# |    fps              | 184      |
# |    time_elapsed     | 44271    |
# |    total_timesteps  | 8186627  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.807    |
# |    n_updates        | 2044156  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13460    |
# |    fps              | 184      |
# |    time_elapsed     | 44301    |
# |    total_timesteps  | 8192123  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22     |
# |    n_updates        | 2045530  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13470    |
# |    fps              | 184      |
# |    time_elapsed     | 44331    |
# |    total_timesteps  | 8197633  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 2046908  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13480    |
# |    fps              | 184      |
# |    time_elapsed     | 44361    |
# |    total_timesteps  | 8203101  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 2048275  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 86.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13490    |
# |    fps              | 184      |
# |    time_elapsed     | 44392    |
# |    total_timesteps  | 8208621  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 2049655  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 86.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13500    |
# |    fps              | 184      |
# |    time_elapsed     | 44422    |
# |    total_timesteps  | 8214143  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 2051035  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 86       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13510    |
# |    fps              | 184      |
# |    time_elapsed     | 44451    |
# |    total_timesteps  | 8219659  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.698    |
# |    n_updates        | 2052414  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 86       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13520    |
# |    fps              | 184      |
# |    time_elapsed     | 44481    |
# |    total_timesteps  | 8225200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 2053799  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 86.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13530    |
# |    fps              | 184      |
# |    time_elapsed     | 44511    |
# |    total_timesteps  | 8230658  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 2055164  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13540    |
# |    fps              | 184      |
# |    time_elapsed     | 44541    |
# |    total_timesteps  | 8236214  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 2056553  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13550    |
# |    fps              | 184      |
# |    time_elapsed     | 44571    |
# |    total_timesteps  | 8241720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 2057929  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13560    |
# |    fps              | 184      |
# |    time_elapsed     | 44601    |
# |    total_timesteps  | 8247271  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49     |
# |    n_updates        | 2059317  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13570    |
# |    fps              | 184      |
# |    time_elapsed     | 44631    |
# |    total_timesteps  | 8252787  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.99     |
# |    n_updates        | 2060696  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13580    |
# |    fps              | 184      |
# |    time_elapsed     | 44661    |
# |    total_timesteps  | 8258287  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 2062071  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13590    |
# |    fps              | 184      |
# |    time_elapsed     | 44690    |
# |    total_timesteps  | 8263769  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.772    |
# |    n_updates        | 2063442  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13600    |
# |    fps              | 184      |
# |    time_elapsed     | 44722    |
# |    total_timesteps  | 8269343  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.676    |
# |    n_updates        | 2064835  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13610    |
# |    fps              | 184      |
# |    time_elapsed     | 44751    |
# |    total_timesteps  | 8274850  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 2066212  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13620    |
# |    fps              | 184      |
# |    time_elapsed     | 44781    |
# |    total_timesteps  | 8280345  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.596    |
# |    n_updates        | 2067586  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13630    |
# |    fps              | 184      |
# |    time_elapsed     | 44810    |
# |    total_timesteps  | 8285851  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.685    |
# |    n_updates        | 2068962  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13640    |
# |    fps              | 184      |
# |    time_elapsed     | 44841    |
# |    total_timesteps  | 8291409  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.774    |
# |    n_updates        | 2070352  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13650    |
# |    fps              | 184      |
# |    time_elapsed     | 44870    |
# |    total_timesteps  | 8296884  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.91     |
# |    n_updates        | 2071720  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13660    |
# |    fps              | 184      |
# |    time_elapsed     | 44900    |
# |    total_timesteps  | 8302421  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 2073105  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13670    |
# |    fps              | 184      |
# |    time_elapsed     | 44930    |
# |    total_timesteps  | 8307924  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 2074480  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13680    |
# |    fps              | 184      |
# |    time_elapsed     | 44960    |
# |    total_timesteps  | 8313433  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 2075858  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13690    |
# |    fps              | 184      |
# |    time_elapsed     | 44990    |
# |    total_timesteps  | 8318958  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.752    |
# |    n_updates        | 2077239  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13700    |
# |    fps              | 184      |
# |    time_elapsed     | 45020    |
# |    total_timesteps  | 8324494  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.978    |
# |    n_updates        | 2078623  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13710    |
# |    fps              | 184      |
# |    time_elapsed     | 45049    |
# |    total_timesteps  | 8329931  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07     |
# |    n_updates        | 2079982  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13720    |
# |    fps              | 184      |
# |    time_elapsed     | 45080    |
# |    total_timesteps  | 8335495  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 2081373  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13730    |
# |    fps              | 184      |
# |    time_elapsed     | 45110    |
# |    total_timesteps  | 8341032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.22     |
# |    n_updates        | 2082757  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13740    |
# |    fps              | 184      |
# |    time_elapsed     | 45140    |
# |    total_timesteps  | 8346534  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 2084133  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13750    |
# |    fps              | 184      |
# |    time_elapsed     | 45170    |
# |    total_timesteps  | 8352021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 2085505  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13760    |
# |    fps              | 184      |
# |    time_elapsed     | 45200    |
# |    total_timesteps  | 8357562  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 2086890  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13770    |
# |    fps              | 184      |
# |    time_elapsed     | 45229    |
# |    total_timesteps  | 8363078  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 2088269  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13780    |
# |    fps              | 184      |
# |    time_elapsed     | 45259    |
# |    total_timesteps  | 8368613  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 2089653  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13790    |
# |    fps              | 184      |
# |    time_elapsed     | 45289    |
# |    total_timesteps  | 8374139  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 2091034  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13800    |
# |    fps              | 184      |
# |    time_elapsed     | 45319    |
# |    total_timesteps  | 8379728  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 2092431  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13810    |
# |    fps              | 184      |
# |    time_elapsed     | 45348    |
# |    total_timesteps  | 8385207  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.964    |
# |    n_updates        | 2093801  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13820    |
# |    fps              | 184      |
# |    time_elapsed     | 45378    |
# |    total_timesteps  | 8390707  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 2095176  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13830    |
# |    fps              | 184      |
# |    time_elapsed     | 45408    |
# |    total_timesteps  | 8396174  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.08     |
# |    n_updates        | 2096543  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13840    |
# |    fps              | 184      |
# |    time_elapsed     | 45437    |
# |    total_timesteps  | 8401668  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 2097916  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13850    |
# |    fps              | 184      |
# |    time_elapsed     | 45468    |
# |    total_timesteps  | 8407172  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 2099292  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13860    |
# |    fps              | 184      |
# |    time_elapsed     | 45498    |
# |    total_timesteps  | 8412677  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.9      |
# |    n_updates        | 2100669  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13870    |
# |    fps              | 184      |
# |    time_elapsed     | 45528    |
# |    total_timesteps  | 8418191  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 2102047  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13880    |
# |    fps              | 184      |
# |    time_elapsed     | 45557    |
# |    total_timesteps  | 8423720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.973    |
# |    n_updates        | 2103429  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13890    |
# |    fps              | 184      |
# |    time_elapsed     | 45587    |
# |    total_timesteps  | 8429183  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.48     |
# |    n_updates        | 2104795  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13900    |
# |    fps              | 184      |
# |    time_elapsed     | 45618    |
# |    total_timesteps  | 8434667  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.973    |
# |    n_updates        | 2106166  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13910    |
# |    fps              | 184      |
# |    time_elapsed     | 45648    |
# |    total_timesteps  | 8440144  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56     |
# |    n_updates        | 2107535  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13920    |
# |    fps              | 184      |
# |    time_elapsed     | 45678    |
# |    total_timesteps  | 8445664  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.84     |
# |    n_updates        | 2108915  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13930    |
# |    fps              | 184      |
# |    time_elapsed     | 45709    |
# |    total_timesteps  | 8451164  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 2110290  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13940    |
# |    fps              | 184      |
# |    time_elapsed     | 45739    |
# |    total_timesteps  | 8456647  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56     |
# |    n_updates        | 2111661  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13950    |
# |    fps              | 184      |
# |    time_elapsed     | 45769    |
# |    total_timesteps  | 8462115  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 2113028  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13960    |
# |    fps              | 184      |
# |    time_elapsed     | 45799    |
# |    total_timesteps  | 8467625  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24     |
# |    n_updates        | 2114406  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13970    |
# |    fps              | 184      |
# |    time_elapsed     | 45831    |
# |    total_timesteps  | 8473090  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 2115772  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13980    |
# |    fps              | 184      |
# |    time_elapsed     | 45861    |
# |    total_timesteps  | 8478609  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 2117152  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 13990    |
# |    fps              | 184      |
# |    time_elapsed     | 45890    |
# |    total_timesteps  | 8484083  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 2118520  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14000    |
# |    fps              | 184      |
# |    time_elapsed     | 45920    |
# |    total_timesteps  | 8489536  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 2119883  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14010    |
# |    fps              | 184      |
# |    time_elapsed     | 45951    |
# |    total_timesteps  | 8495018  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 2121254  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14020    |
# |    fps              | 184      |
# |    time_elapsed     | 45981    |
# |    total_timesteps  | 8500556  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 2122638  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14030    |
# |    fps              | 184      |
# |    time_elapsed     | 46011    |
# |    total_timesteps  | 8506077  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 2124019  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14040    |
# |    fps              | 184      |
# |    time_elapsed     | 46042    |
# |    total_timesteps  | 8511634  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 2125408  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14050    |
# |    fps              | 184      |
# |    time_elapsed     | 46072    |
# |    total_timesteps  | 8517183  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 2126795  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14060    |
# |    fps              | 184      |
# |    time_elapsed     | 46102    |
# |    total_timesteps  | 8522714  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 2128178  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14070    |
# |    fps              | 184      |
# |    time_elapsed     | 46132    |
# |    total_timesteps  | 8528232  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 2129557  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14080    |
# |    fps              | 184      |
# |    time_elapsed     | 46162    |
# |    total_timesteps  | 8533759  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 2130939  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14090    |
# |    fps              | 184      |
# |    time_elapsed     | 46193    |
# |    total_timesteps  | 8539271  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 2132317  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14100    |
# |    fps              | 184      |
# |    time_elapsed     | 46223    |
# |    total_timesteps  | 8544805  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56     |
# |    n_updates        | 2133701  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 83.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14110    |
# |    fps              | 184      |
# |    time_elapsed     | 46254    |
# |    total_timesteps  | 8550392  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 2135097  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14120    |
# |    fps              | 184      |
# |    time_elapsed     | 46284    |
# |    total_timesteps  | 8555898  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 2136474  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14130    |
# |    fps              | 184      |
# |    time_elapsed     | 46313    |
# |    total_timesteps  | 8561383  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.973    |
# |    n_updates        | 2137845  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14140    |
# |    fps              | 184      |
# |    time_elapsed     | 46343    |
# |    total_timesteps  | 8566884  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 2139220  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14150    |
# |    fps              | 184      |
# |    time_elapsed     | 46374    |
# |    total_timesteps  | 8572464  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96     |
# |    n_updates        | 2140615  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14160    |
# |    fps              | 184      |
# |    time_elapsed     | 46404    |
# |    total_timesteps  | 8578015  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 2142003  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14170    |
# |    fps              | 184      |
# |    time_elapsed     | 46434    |
# |    total_timesteps  | 8583539  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 2143384  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14180    |
# |    fps              | 184      |
# |    time_elapsed     | 46464    |
# |    total_timesteps  | 8589043  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 2144760  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 83.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14190    |
# |    fps              | 184      |
# |    time_elapsed     | 46494    |
# |    total_timesteps  | 8594603  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 2146150  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14200    |
# |    fps              | 184      |
# |    time_elapsed     | 46523    |
# |    total_timesteps  | 8600074  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 2147518  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14210    |
# |    fps              | 184      |
# |    time_elapsed     | 46554    |
# |    total_timesteps  | 8605619  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.964    |
# |    n_updates        | 2148904  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14220    |
# |    fps              | 184      |
# |    time_elapsed     | 46584    |
# |    total_timesteps  | 8611143  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.93     |
# |    n_updates        | 2150285  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14230    |
# |    fps              | 184      |
# |    time_elapsed     | 46614    |
# |    total_timesteps  | 8616678  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.13     |
# |    n_updates        | 2151669  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14240    |
# |    fps              | 184      |
# |    time_elapsed     | 46643    |
# |    total_timesteps  | 8622219  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 2153054  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14250    |
# |    fps              | 184      |
# |    time_elapsed     | 46672    |
# |    total_timesteps  | 8627735  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 2154433  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14260    |
# |    fps              | 184      |
# |    time_elapsed     | 46702    |
# |    total_timesteps  | 8633244  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 2155810  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14270    |
# |    fps              | 184      |
# |    time_elapsed     | 46732    |
# |    total_timesteps  | 8638813  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.748    |
# |    n_updates        | 2157203  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14280    |
# |    fps              | 184      |
# |    time_elapsed     | 46762    |
# |    total_timesteps  | 8644333  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.32     |
# |    n_updates        | 2158583  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14290    |
# |    fps              | 184      |
# |    time_elapsed     | 46791    |
# |    total_timesteps  | 8649879  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 2159969  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14300    |
# |    fps              | 184      |
# |    time_elapsed     | 46821    |
# |    total_timesteps  | 8655376  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 2161343  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 14310    |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16440    |
# |    fps              | 184      |
# |    time_elapsed     | 53261    |
# |    total_timesteps  | 9838523  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67     |
# |    n_updates        | 2457130  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16450    |
# |    fps              | 184      |
# |    time_elapsed     | 53291    |
# |    total_timesteps  | 9844067  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 2458516  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16460    |
# |    fps              | 184      |
# |    time_elapsed     | 53321    |
# |    total_timesteps  | 9849622  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 2459905  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16470    |
# |    fps              | 184      |
# |    time_elapsed     | 53351    |
# |    total_timesteps  | 9855180  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 2461294  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16480    |
# |    fps              | 184      |
# |    time_elapsed     | 53380    |
# |    total_timesteps  | 9860640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 2462659  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16490    |
# |    fps              | 184      |
# |    time_elapsed     | 53410    |
# |    total_timesteps  | 9866181  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.762    |
# |    n_updates        | 2464045  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16500    |
# |    fps              | 184      |
# |    time_elapsed     | 53439    |
# |    total_timesteps  | 9871676  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.965    |
# |    n_updates        | 2465418  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16510    |
# |    fps              | 184      |
# |    time_elapsed     | 53470    |
# |    total_timesteps  | 9877230  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 2466807  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16520    |
# |    fps              | 184      |
# |    time_elapsed     | 53499    |
# |    total_timesteps  | 9882732  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 2468182  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16530    |
# |    fps              | 184      |
# |    time_elapsed     | 53529    |
# |    total_timesteps  | 9888228  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 2469556  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16540    |
# |    fps              | 184      |
# |    time_elapsed     | 53558    |
# |    total_timesteps  | 9893752  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.79     |
# |    n_updates        | 2470937  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16550    |
# |    fps              | 184      |
# |    time_elapsed     | 53589    |
# |    total_timesteps  | 9899327  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.998    |
# |    n_updates        | 2472331  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16560    |
# |    fps              | 184      |
# |    time_elapsed     | 53619    |
# |    total_timesteps  | 9904819  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 2473704  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16570    |
# |    fps              | 184      |
# |    time_elapsed     | 53649    |
# |    total_timesteps  | 9910356  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.27     |
# |    n_updates        | 2475088  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16580    |
# |    fps              | 184      |
# |    time_elapsed     | 53679    |
# |    total_timesteps  | 9915903  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02     |
# |    n_updates        | 2476475  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16590    |
# |    fps              | 184      |
# |    time_elapsed     | 53709    |
# |    total_timesteps  | 9921424  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.79     |
# |    n_updates        | 2477855  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.1     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16600    |
# |    fps              | 184      |
# |    time_elapsed     | 53738    |
# |    total_timesteps  | 9926904  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.648    |
# |    n_updates        | 2479225  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16610    |
# |    fps              | 184      |
# |    time_elapsed     | 53767    |
# |    total_timesteps  | 9932467  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 2480616  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16620    |
# |    fps              | 184      |
# |    time_elapsed     | 53798    |
# |    total_timesteps  | 9937949  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49     |
# |    n_updates        | 2481987  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16630    |
# |    fps              | 184      |
# |    time_elapsed     | 53827    |
# |    total_timesteps  | 9943497  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 2483374  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16640    |
# |    fps              | 184      |
# |    time_elapsed     | 53856    |
# |    total_timesteps  | 9948937  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 2484734  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16650    |
# |    fps              | 184      |
# |    time_elapsed     | 53886    |
# |    total_timesteps  | 9954487  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 2486121  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 84.6     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16660    |
# |    fps              | 184      |
# |    time_elapsed     | 53916    |
# |    total_timesteps  | 9959966  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 2487491  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 85.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16670    |
# |    fps              | 184      |
# |    time_elapsed     | 53945    |
# |    total_timesteps  | 9965422  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 2488855  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85       |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16680    |
# |    fps              | 184      |
# |    time_elapsed     | 53975    |
# |    total_timesteps  | 9970940  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.612    |
# |    n_updates        | 2490234  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16690    |
# |    fps              | 184      |
# |    time_elapsed     | 54004    |
# |    total_timesteps  | 9976409  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.844    |
# |    n_updates        | 2491602  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16700    |
# |    fps              | 184      |
# |    time_elapsed     | 54034    |
# |    total_timesteps  | 9981952  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.15     |
# |    n_updates        | 2492987  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16710    |
# |    fps              | 184      |
# |    time_elapsed     | 54063    |
# |    total_timesteps  | 9987414  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.928    |
# |    n_updates        | 2494353  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16720    |
# |    fps              | 184      |
# |    time_elapsed     | 54093    |
# |    total_timesteps  | 9992927  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 2495731  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 85.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 16730    |
# |    fps              | 184      |
# |    time_elapsed     | 54122    |
# |    total_timesteps  | 9998442  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 2497110  |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training done
# Time taken: 15:02:11
# Model saved to Google Drive

# %%
# torch.cuda.empty_cache()
# del model
# del env
